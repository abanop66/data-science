# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

import cv2

# %%
pil=Image.open("../images/thor.jpg")

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x246 at 0x1B7B9BD1388>

# %%
arr=np.array(pil)

# %%
red=arr.copy()

# %%
red[:,:,[0,1]]=255

# %%
plt.imshow(red)

# %%
frame=cv2.imread("../images/thor.jpg")

# %%
plt.imshow(frame)

# %%
rgb= cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
