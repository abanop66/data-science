# %%
import pandas as pd

# %%
list=[1,2,3,4]
list
# Out:
# [1, 2, 3, 4]

# %%
df= pd.DataFrame(list)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
df= pd.DataFrame([list])
df
# Out:
#    0  1  2  3
# 0  1  2  3  4

# %%
d={'apple':[1,2,3],'or':[1,2,3],'orange':[4,5,6]}
d
# Out:
# {'apple': [1, 2, 3], 'or': [1, 2, 3], 'orange': [4, 5, 6]}

# %%
s=pd.Series({'apple':[1,2,3],'or':[1,2,3],'orange':[4,5,6]})
s
# Out:
# apple     [1, 2, 3]
# or        [1, 2, 3]
# orange    [4, 5, 6]
# dtype: object

# %%
#data= pd.read_csv("path")
df= pd.DataFrame(data={
    'apple':[1,2,0],'orange':[4,5,7],'or':[4,5,6]
},index=['aba','bob','con'])
df
# Out:
#      apple  orange  or
# aba      1       4   4
# bob      2       5   5
# con      0       7   6

# %% [markdown]
# # columns and rows difference

# %%
#columns
df['apple']
# Out:
# aba    1
# bob    2
# con    0
# Name: apple, dtype: int64

# %%
#rows or in this case the name ,,, always use loc when it comes to rows
df.loc['bob']
# Out:
# apple     2
# orange    5
# or        5
# Name: bob, dtype: int64

# %%
#df.apple
df.loc['bob'].apple
# Out:
# 2

# %% [markdown]
# # transpose and describe

# %%
df.describe().transpose()
# Out:
#         count      mean       std  min  25%  50%  75%  max
# apple     3.0  1.000000  1.000000  0.0  0.5  1.0  1.5  2.0
# orange    3.0  5.333333  1.527525  4.0  4.5  5.0  6.0  7.0
# or        3.0  5.000000  1.000000  4.0  4.5  5.0  5.5  6.0
#        apple    orange   or
# count    3.0  3.000000  3.0
# mean     1.0  5.333333  5.0
# std      1.0  1.527525  1.0
# min      0.0  4.000000  4.0
# 25%      0.5  4.500000  4.5
# 50%      1.0  5.000000  5.0
# 75%      1.5  6.000000  5.5
# max      2.0  7.000000  6.0

# %%
df.describe()

# %%
print(df.orange.mean())
print(df.orange.min())
# Out:
# 5.333333333333333
# 4

# %%
df.describe().orange
# Out:
# count    3.000000
# mean     5.333333
# std      1.527525
# min      4.000000
# 25%      4.500000
# 50%      5.000000
# 75%      6.000000
# max      7.000000
# Name: orange, dtype: float64

# %%
round(df.describe().orange.loc['mean'])
# Out:
# 5.0

# %%
l1=['a','b','c']
l2=[1,2,3]
s1=pd.Series(l2,l1)    
s1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
df2=pd.DataFrame([l2,l2,[l1[0],l2[1],l1[2]]],columns=l1)
df2
# Out:
#    a  b  c
# 0  1  2  3
# 1  1  2  3
# 2  a  2  c

# %%
data=pd.read_csv("E:\A python\company data.csv",index_col=0)

# %%
data.tail(30)
# Out:
#        account length  area code phone number international plan  \
# state
# AL                 32        510     404-9680                 no
# CO                 68        408     338-9398                 no
# NH                 64        408     394-2445                 no
# NM                 25        415     381-2709                 no
# OR                 65        415     397-5060                 no
# LA                179        408     415-2393                 no
# NE                 94        415     377-1765                 no
# MN                 62        415     409-2111                 no
# MI                127        415     401-3170                 no
# AR                116        408     405-5681                 no
# KS                 70        408     411-4582                 no
# WV                 94        510     355-5009                yes
# AK                126        415     372-3750                 no
# ...

# %%
data.describe().transpose()
# Out:
#                         count        mean        std     min      25%     50%  \
# account length          199.0  100.748744  39.380778    6.00   73.500   97.00
# area code               199.0  433.065327  40.611497  408.00  408.000  415.00
# number vmail messages   199.0    7.804020  13.743935    0.00    0.000    0.00
# total day minutes       199.0  185.862814  53.027743   58.20  150.350  186.10
# total day calls         199.0  100.633166  19.561638   47.00   89.000  101.00
# total day charge        199.0   31.597337   9.014950    9.89   25.560   31.64
# total eve minutes       199.0  195.367337  51.521649   31.20  163.350  195.00
# total eve calls         199.0   98.809045  19.885117   46.00   85.000   98.00
# total eve charge        199.0   16.606533   4.379042    2.65   13.885   16.58
# total night minutes     199.0  196.994975  52.481158   57.50  162.100  195.20
# total night calls       199.0  100.628141  20.731141   53.00   86.500  103.00
# ...

# %% [markdown]
# # datetime

# %%
import datetime

now=datetime.datetime.now()
print(now)
print(now.year)
print(now.time())
print(now.date())
# Out:
# 2020-09-29 14:38:31.988649
# 2020
# 14:38:31.988649
# 2020-09-29
